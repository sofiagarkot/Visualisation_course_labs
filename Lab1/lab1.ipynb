# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_csv('GLB.Ts_dSST.csv', header=1)
df.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.29 -0.18 -0.11 -0.19 -0.11 -0.23 -0.21 -0.09 -0.16 -0.23 -0.20
# 1  1881 -0.15 -0.17  0.04  0.04  0.02 -0.20 -0.06 -0.02 -0.13 -0.20 -0.21
# 2  1882  0.15  0.15  0.04 -0.18 -0.16 -0.26 -0.20 -0.05 -0.10 -0.24 -0.16
# 3  1883 -0.31 -0.39 -0.13 -0.17 -0.20 -0.12 -0.08 -0.15 -0.20 -0.14 -0.22
# 4  1884 -0.15 -0.08 -0.37 -0.42 -0.36 -0.40 -0.34 -0.26 -0.27 -0.24 -0.30
#
#     Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0 -0.23 -0.19   ***   *** -0.14 -0.18 -0.20
# 1 -0.10 -0.10  -.11  -.18  0.03 -0.09 -0.18
# 2 -0.24 -0.10  -.09   .06 -0.10 -0.17 -0.17
# 3 -0.16 -0.19  -.20  -.31 -0.16 -0.12 -0.19
# 4 -0.28 -0.29  -.28  -.13 -0.39 -0.34 -0.27

# %%
df.columns
# Out:
# Index(['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec', 'J-D', 'D-N', 'DJF', 'MAM', 'JJA', 'SON'],
#       dtype='object')

# %%
df['Year']
# Out:
# 0      1880
# 1      1881
# 2      1882
# 3      1883
# 4      1884
#        ...
# 133    2013
# 134    2014
# 135    2015
# 136    2016
# 137    2017
# Name: Year, Length: 138, dtype: int64

# %%
df['Year']<=1899
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 133    False
# 134    False
# 135    False
# 136    False
# 137    False
# Name: Year, Length: 138, dtype: bool

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
needed_column_indices = [list(df.columns).index(m) for m in months]

# %%
df[df['Year']<=1899].iloc[:,needed_column_indices].mean().mean()
# Out:
# -0.22804166666666667

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(30,20))
# plt.axis('off')
plt.scatter(df['Year'], df['J-D'], marker="o", color='black')
plt.scatter(df['Year'], df['J-D'], marker=".", color='orange')
plt.grid()
plt.show()
